# %%
import pandas as pd 
import numpy as np 


import pandas as pd
import numpy as np




df1 = pd.read_csv("C:\\Users\\yuna\\OneDrive\\Documents\\카카오톡 받은 파일\\뉴런장소.csv",encoding='CP949')
df1
# Out:
#                     STORE_SN  AREA_SD_CODE AREA_DETAIL_CODE  \
# 0      S000000_1607331778801            11           110405
# 1      S000000_1607331778802            11           110506
# 2      S000000_1607331778803            11           110508
# 3      S000000_1607331778804            11           110606
# 4      S000000_1607331778805            11           110722
# ...                      ...           ...              ...
# 19841  S988016_1622432708515             9           093831
# 19842  S989046_1626071332695            14           142113
# 19843  S990140_1623823558724             1           012451
# 19844  S992906_1625723001020            13           130249
# 19845  S998882_1624433872820             3           030101
#
#                      USER_SN   PREF_SN      STORE_NM  \
# 0      U190225_1558789237854  10000000          선희식당
# 1      U190225_1558789237854  10000000           대박집
# 2      U190225_1558789237854  10000000          찐한식당
# ...

# %%
df11 = df1[["STORE_SN","STORE_NM"]]
df11
# Out:
#                     STORE_SN      STORE_NM
# 0      S000000_1607331778801          선희식당
# 1      S000000_1607331778802           대박집
# 2      S000000_1607331778803          찐한식당
# 3      S000000_1607331778804         생극해장국
# 4      S000000_1607331778805         동궁한정식
# ...                      ...           ...
# 19841  S988016_1622432708515          모산목장
# 19842  S989046_1626071332695  화원 오시아노 관광단지
# 19843  S990140_1623823558724         장충체육관
# 19844  S992906_1625723001020          마리서사
# 19845  S998882_1624433872820      안지랑 곱창골목
#
# [19846 rows x 2 columns]

# %%
df2 = pd.read_csv("C:\\Users\\yuna\\OneDrive\\Documents\\카카오톡 받은 파일\\국내미술관(한국문화정보원).csv")
df2
# Out:
#                       id lclas mlsfc                fclt_name ctprvn_nm  \
# 0    KCDMART21N000000001  문화시설   미술관              국립현대미술관(과천)       경기도
# 1    KCDMART21N000000002  문화시설   미술관              국립현대미술관(서울)     서울특별시
# 2    KCDMART21N000000003  문화시설   미술관             국립현대미술관(덕수궁)     서울특별시
# 3    KCDMART21N000000004  문화시설   미술관      국립현대미술관 미술품수장센터(청주)      충청북도
# 4    KCDMART21N000000005  문화시설   미술관                  겸재정선미술관     서울특별시
# ..                   ...   ...   ...                      ...       ...
# 265  KCDMART21N000000266  문화시설   미술관                 제주옹기숨미술관   제주특별자치도
# 266  KCDMART21N000000267  문화시설   미술관                   제주유리의성   제주특별자치도
# 267  KCDMART21N000000268  문화시설   미술관                   제주조각공원   제주특별자치도
# 268  KCDMART21N000000269  문화시설   미술관  빛의 벙커 (제주 성산 AMIEX 전시관)   제주특별자치도
# 269  KCDMART21N000000270  문화시설   미술관                   김택화미술관   제주특별자치도
#
#     sgnr_nm  legaldong_cd legalemd_nm   adstrd_cd adstrd_nm  ...  \
# ...

# %%
inner_df = pd.merge(df11, df2, left_on = "STORE_NM", right_on = "fclt_name")
inner_df #
# Out:
#                  STORE_SN   STORE_NM                   id lclas mlsfc  \
# 0   S106026_1622432708465      남송미술관  KCDMART21N000000102  문화시설   미술관
# 1   S120275_1623823558684      자하미술관  KCDMART21N000000037  문화시설   미술관
# 2   S129762_1622432708770  이천시립월전미술관  KCDMART21N000000097  문화시설   미술관
# 3   S129770_1622432708514      모란미술관  KCDMART21N000000106  문화시설   미술관
# 4   S130264_1624433872609      한광미술관  KCDMART21N000000056  문화시설   미술관
# ..                    ...        ...                  ...   ...   ...
# 62  S631003_1622432708530    백남준아트센터  KCDMART21N000000090  문화시설   미술관
# 63  S631278_1622432708434     경기도미술관  KCDMART21N000000087  문화시설   미술관
# 64  S743034_1625110393751      일현미술관  KCDMART21N000000153  문화시설   미술관
# 65  S759595_1620809163675    제주도립미술관  KCDMART21N000000253  문화시설   미술관
# 66  S798017_1625110393684    국제현대미술관  KCDMART21N000000144  문화시설   미술관
#
#     fclt_name ctprvn_nm sgnr_nm  legaldong_cd legalemd_nm  ...  \
# ...

# %%
right_merge = pd.merge(df11, df2, left_on = "STORE_NM", right_on = "fclt_name", how = "right")
right_merge
# Out:
#                   STORE_SN STORE_NM                   id lclas mlsfc  \
# 0                      NaN      NaN  KCDMART21N000000001  문화시설   미술관
# 1                      NaN      NaN  KCDMART21N000000002  문화시설   미술관
# 2                      NaN      NaN  KCDMART21N000000003  문화시설   미술관
# 3                      NaN      NaN  KCDMART21N000000004  문화시설   미술관
# 4    S190530_1564369680107  겸재정선미술관  KCDMART21N000000005  문화시설   미술관
# ..                     ...      ...                  ...   ...   ...
# 266                    NaN      NaN  KCDMART21N000000266  문화시설   미술관
# 267                    NaN      NaN  KCDMART21N000000267  문화시설   미술관
# 268                    NaN      NaN  KCDMART21N000000268  문화시설   미술관
# 269                    NaN      NaN  KCDMART21N000000269  문화시설   미술관
# 270                    NaN      NaN  KCDMART21N000000270  문화시설   미술관
#
#                    fclt_name ctprvn_nm sgnr_nm  legaldong_cd legalemd_nm  ...  \
# ...

# %%
right_merge.shape
# Out:
# (271, 81)

# %%
Final_df= right_merge.loc[right_merge["STORE_NM"] != right_merge["fclt_name"]]
Final_df
# Out:
#     STORE_SN STORE_NM                   id lclas mlsfc  \
# 0        NaN      NaN  KCDMART21N000000001  문화시설   미술관
# 1        NaN      NaN  KCDMART21N000000002  문화시설   미술관
# 2        NaN      NaN  KCDMART21N000000003  문화시설   미술관
# 3        NaN      NaN  KCDMART21N000000004  문화시설   미술관
# 5        NaN      NaN  KCDMART21N000000006  문화시설   미술관
# ..       ...      ...                  ...   ...   ...
# 266      NaN      NaN  KCDMART21N000000266  문화시설   미술관
# 267      NaN      NaN  KCDMART21N000000267  문화시설   미술관
# 268      NaN      NaN  KCDMART21N000000268  문화시설   미술관
# 269      NaN      NaN  KCDMART21N000000269  문화시설   미술관
# 270      NaN      NaN  KCDMART21N000000270  문화시설   미술관
#
#                    fclt_name ctprvn_nm sgnr_nm  legaldong_cd legalemd_nm  ...  \
# 0                국립현대미술관(과천)       경기도     과천시    4129010400         막계동  ...
# 1                국립현대미술관(서울)     서울특별시     종로구    1111014200         소격동  ...
# ...

# %%
Final_df.shape  # 중복값 67개 사라짐
# Out:
# (204, 81)

# %%
Fixed_Art_Data = Final_df.drop(["STORE_SN","STORE_NM"],axis = 1)
Fixed_Art_Data
# Out:
#                       id lclas mlsfc                fclt_name ctprvn_nm  \
# 0    KCDMART21N000000001  문화시설   미술관              국립현대미술관(과천)       경기도
# 1    KCDMART21N000000002  문화시설   미술관              국립현대미술관(서울)     서울특별시
# 2    KCDMART21N000000003  문화시설   미술관             국립현대미술관(덕수궁)     서울특별시
# 3    KCDMART21N000000004  문화시설   미술관      국립현대미술관 미술품수장센터(청주)      충청북도
# 5    KCDMART21N000000006  문화시설   미술관                   남서울미술관     서울특별시
# ..                   ...   ...   ...                      ...       ...
# 266  KCDMART21N000000266  문화시설   미술관                 제주옹기숨미술관   제주특별자치도
# 267  KCDMART21N000000267  문화시설   미술관                   제주유리의성   제주특별자치도
# 268  KCDMART21N000000268  문화시설   미술관                   제주조각공원   제주특별자치도
# 269  KCDMART21N000000269  문화시설   미술관  빛의 벙커 (제주 성산 AMIEX 전시관)   제주특별자치도
# 270  KCDMART21N000000270  문화시설   미술관                   김택화미술관   제주특별자치도
#
#     sgnr_nm  legaldong_cd legalemd_nm   adstrd_cd adstrd_nm  ...  \
# ...

# %%
Fixed_Art_Data.to_csv("C:\\Users\\yuna\\Downloads\\Fixed_Art_Data.csv", index = None)
